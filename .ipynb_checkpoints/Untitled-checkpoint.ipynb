# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
fp = "gadm36_TWN.gpkg"
map_df = gpd.read_file(fp)

# %%
df_2008 = pd.read_excel("2008/total.xls")

# %%
df_2008.head(4)
# Out:
#   第12任總統、副總統選舉候選人得票數(率)表 Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0                   行政區別    候選人總得票數  (1)謝長廷、蘇貞昌        NaN  (2)馬英九、蕭萬長
# 1                    NaN        NaN         得票數        得票率         得票數
# 2                    總　計   13103963     5444949    41.5519     7659014
# 3                   　臺北市    1604802      593256    36.9676     1011546
#
#   Unnamed: 5
# 0        NaN
# 1        得票率
# 2    58.4481
# 3    63.0324

# %%
df_2008 = df_2008.drop([0, 1 , 2]).reset_index(drop=True).drop([df_2008.columns[3],df_2008.columns[5]],
                                                      axis='columns')
df_2008.columns = ['City', 'Total', 'DPP', 'KMT']

# %%
df_2008.head(2)
# Out:
#    City    Total     DPP      KMT
# 0  　臺北市  1604802  593256  1011546
# 1  　高雄市   909619  440367   469252

# %%
print(map_df['NL_NAME_2'], df_2008['City'])
# Out:
# 0      金門縣
# 1     馬祖列島
# 2      高雄市
# 3      新北市
# 4       台中
# 5       台南
# 6      台北市
# 7      彰化縣
# 8      嘉義市
# 9      嘉義縣
# 10     新竹市
# 11     新竹縣
# 12     花蓮縣
# 13     基隆市
# 14     苗栗縣
# 15     南投縣
# 16     澎湖縣
# 17     屏東縣
# 18     台東縣
# 19     桃園市
# 20     宜蘭縣
# 21     雲林縣
# Name: NL_NAME_2, dtype: object 0      台北市
# 1     　高雄市
# 2      新北市
# 3     　宜蘭縣
# 4      桃園市
# 5     　新竹縣
# 6     　苗栗縣
# 7     　臺中縣
# 8     　彰化縣
# 9     　南投縣
# 10    　雲林縣
# 11    　嘉義縣
# 12    　臺南縣
# 13    　高雄縣
# 14    　屏東縣
# 15     台東縣
# 16    　花蓮縣
# 17    　澎湖縣
# 18    　基隆市
# 19    　新竹市
# 20      台中
# 21    　嘉義市
# 22      台南
# 23    　金門縣
# 24    馬祖列島
# Name: City, dtype: object

# %%
df_2008.at[0, 'City'] = '台北市'
df_2008.at[24, 'City'] = '馬祖列島'
df_2008.at[22, 'City'] = '台南'
df_2008.at[15, 'City'] = '台東縣'
df_2008.at[20, 'City'] = '台中'
df_2008.at[2, 'City'] = '新北市'
df_2008.at[4, 'City'] = '桃園市'

# %%
df_2008.at[20, 'Total'] = df_2008.at[7, 'Total'] + df_2008.at[ 20, 'Total']
df_2008.at[20, 'DPP'] = df_2008.at[7, 'DPP'] + df_2008.at[ 20, 'DPP']
df_2008.at[20, 'KMT'] = df_2008.at[7, 'KMT'] + df_2008.at[ 20, 'KMT']

# %%
df_2008.at[22, 'Total'] = df_2008.at[22, 'Total'] + df_2008.at[ 12, 'Total']
df_2008.at[22, 'DPP'] = df_2008.at[22, 'DPP'] + df_2008.at[ 12, 'DPP']
df_2008.at[22, 'KMT'] = df_2008.at[22, 'KMT'] + df_2008.at[ 12, 'KMT']

# %%
df_2008.at[1, 'Total'] = df_2008.at[13, 'Total'] + df_2008.at[ 1, 'Total']
df_2008.at[1, 'DPP'] = df_2008.at[13, 'DPP'] + df_2008.at[ 1, 'DPP']
df_2008.at[1, 'KMT'] = df_2008.at[13, 'KMT'] + df_2008.at[ 1, 'KMT']

# %%
df_2008 = df_2008.drop([7, 12, 13]).reset_index(drop=True)

# %%
map_df.rename(columns={'NL_NAME_2': 'City'}, inplace=True)

# %%
map_df
# Out:
#    GID_0  NAME_0    GID_1      NAME_1 NL_NAME_1       GID_2          NAME_2  \
# 0    TWN  Taiwan  TWN.1_1      Fujian        福建   TWN.1.1_1          Kinmen
# 1    TWN  Taiwan  TWN.1_1      Fujian        福建   TWN.1.2_1       Lienkiang
# 2    TWN  Taiwan  TWN.2_1   Kaohsiung        高雄   TWN.2.1_1       Kaohsiung
# 3    TWN  Taiwan  TWN.3_1  New Taipei        新北   TWN.3.1_1      New Taipei
# 4    TWN  Taiwan  TWN.4_1    Taichung        台中   TWN.4.1_1        Taichung
# 5    TWN  Taiwan  TWN.5_1      Tainan        台南   TWN.5.1_1          Tainan
# 6    TWN  Taiwan  TWN.6_1      Taipei        台北   TWN.6.1_1          Taipei
# 7    TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.1_1        Changhua
# 8    TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.2_1     Chiayi City
# 9    TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.3_1   Chiayi County
# 10   TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.4_1    Hsinchu City
# 11   TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.5_1  Hsinchu County
# 12   TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.6_1         Hualien
# 13   TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.7_1         Keelung
# 14   TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.8_1          Miaoli
# 15   TWN  Taiwan  TWN.7_1      Taiwan        台灣   TWN.7.9_1          Nantou
# 16   TWN  Taiwan  TWN.7_1      Taiwan        台灣  TWN.7.10_1          Penghu
# 17   TWN  Taiwan  TWN.7_1      Taiwan        台灣  TWN.7.11_1        Pingtung
# 18   TWN  Taiwan  TWN.7_1      Taiwan        台灣  TWN.7.12_1         Taitung
# 19   TWN  Taiwan  TWN.7_1      Taiwan        台灣  TWN.7.13_1         Taoyuan
# 20   TWN  Taiwan  TWN.7_1      Taiwan        台灣  TWN.7.14_1           Yilan
# 21   TWN  Taiwan  TWN.7_1      Taiwan        台灣  TWN.7.15_1           Yulin
#
#                         VARNAME_2  City     TYPE_2             ENGTYPE_2  \
# 0                     Jīnmén Xiàn   金門縣       Xiàn                County
# 1       Mǎzǔ Lièdǎo|Matsu Islands  馬祖列島       Xiàn                County
# 2                    Gāoxióng Shì   高雄市  Zhíxiáshì  Special Municipality
# 3                      Xīnběi Shì   新北市  Zhíxiáshì  Special Municipality
# 4                   Taichung City    台中  Zhíxiáshì  Special Municipality
# 5                     Tainan City    台南  Zhíxiáshì  Special Municipality
# 6                      Táiběi Shì   台北市  Zhíxiáshì  Special Municipality
# 7                   Zhānghuà Xiàn   彰化縣       Xiàn                County
# 8                       Jiāyì Shì   嘉義市        Shì       Provincial City
# 9                      Jiāyì Xiàn   嘉義縣       Xiàn                County
# 10                     Xīnzhú Shì   新竹市        Shì       Provincial City
# 11                    Xīnzhú Xiàn   新竹縣       Xiàn                County
# 12                   Huālián Xiàn   花蓮縣       Xiàn                County
# 13  Jīlóng Shì | Jilong | Chilung   基隆市        Shì       Provincial City
# 14                    Miáolì Xiàn   苗栗縣       Xiàn                County
# 15                    Nántóu Xiàn   南投縣       Xiàn                County
# 16                    Pēnghú Xiàn   澎湖縣       Xiàn                County
# 17                  Píngdōng Xiàn   屏東縣       Xiàn                County
# 18                   Táidōng Xiàn   台東縣       Xiàn                County
# 19                    Táoyuán Shì   桃園市  Zhíxiáshì  Special Municipality
# 20                     Yílán Xiàn   宜蘭縣       Xiàn                County
# 21                    Yúnlín Xiàn   雲林縣       Xiàn                County
#
#     CC_2    HASC_2                                           geometry
# 0   None  TW.FK.KM  MULTIPOLYGON (((118.39986 24.43569, 118.39792 ...
# 1   None  TW.FK.LK  MULTIPOLYGON (((120.08598 26.38403, 120.08598 ...
# 2   None  TW.KH.KS  MULTIPOLYGON (((120.33264 22.55320, 120.33264 ...
# 3   None  TW.NT.TP  MULTIPOLYGON (((122.07875 25.63431, 122.07875 ...
# 4   None  TW.TG.TU  MULTIPOLYGON (((120.50069 24.26875, 120.50069 ...
# 5   None  TW.TN.TI  MULTIPOLYGON (((120.13875 22.99792, 120.13736 ...
# 6   None  TW.TP.TC  MULTIPOLYGON (((121.41348 25.16764, 121.41348 ...
# 7   None  TW.TA.CG  MULTIPOLYGON (((120.30180 23.90319, 120.30209 ...
# 8   None  TW.TA.CS  MULTIPOLYGON (((120.42706 23.50177, 120.43077 ...
# 9   None  TW.TA.CH  MULTIPOLYGON (((120.12930 23.35375, 120.12930 ...
# 10  None  TW.TA.HS  MULTIPOLYGON (((120.94930 24.83847, 120.95695 ...
# 11  None  TW.TA.HS  MULTIPOLYGON (((121.41409 24.58442, 121.41547 ...
# 12  None  TW.TA.HL  MULTIPOLYGON (((121.56486 23.73931, 121.56486 ...
# 13  None  TW.TA.CL  MULTIPOLYGON (((121.78680 25.19514, 121.78680 ...
# 14  None  TW.TA.ML  MULTIPOLYGON (((120.63292 24.44597, 120.63292 ...
# 15  None  TW.TA.NT  MULTIPOLYGON (((120.73636 23.61386, 120.73368 ...
# 16  None  TW.TA.PH  MULTIPOLYGON (((119.60152 23.78809, 119.60152 ...
# 17  None  TW.TA.PT  MULTIPOLYGON (((120.87681 22.00236, 120.87653 ...
# 18  None  TW.TA.TT  MULTIPOLYGON (((121.16736 22.75236, 121.16681 ...
# 19  None  TW.TA.TY  MULTIPOLYGON (((121.48055 24.66928, 121.47849 ...
# 20  None  TW.TA.IL  MULTIPOLYGON (((121.32659 24.43295, 121.32352 ...
# 21  None  TW.TA.YL  MULTIPOLYGON (((120.73636 23.61386, 120.73874 ...

# %%
df_2008['City'] = [city.strip() for city in df_2008['City']]

# %%
df_outer = pd.merge(map_df, df_2008, on='City', how='outer')

# %%
parties = {'KMT': 'Blues',
               'DPP': 'Greens'}
winning_party = []
for index, row in df_outer.iterrows():
    if row['KMT'] >row['DPP']:
        print(row['KMT'])
        winning_party.append('KMT')
    else:
        winning_party.append('DPP')
df_outer['winning_party'] = winning_party
# Out:
# 33384
# 4329
# 822585
# 1359419
# 1377375
# 1011546
# 419700
# 79713
# 145930
# 208445
# 137604
# 152327
# 227069
# 179630
# 25037
# 81668
# 693602
# 130951

# %%
margin = []
for index, row in df_outer.iterrows():
    if row['winning_party'] == 'KMT':
        print(row['KMT'], row['Total'])
        margin.append(row['KMT'] / row['Total'])
    else:
         margin.append(row['DPP'] / row['Total'])
# Out:
# 33384 35094
# 4329 4549
# 822585 1636852
# 1359419 2226334
# 1377375 2311538
# 1011546 1604802
# 419700 728834
# 79713 152155
# 145930 225564
# 208445 281623
# 137604 177607
# 152327 224889
# 227069 319864
# 179630 289585
# 25037 43218
# 81668 111382
# 693602 1073018
# 130951 254651

# %%
df_outer['margin'] = margin

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, ax = plt.subplots(figsize=(15, 5))
divider = make_axes_locatable(ax)

for party, color in parties.items():

    cax = divider.append_axes('right', size='2%', pad=0.6)
    cax.set_xlabel(party)

    df_outer[df_outer.winning_party == party].plot(column='margin', cmap=color,
                                         legend=True, ax=ax, cax=cax)
